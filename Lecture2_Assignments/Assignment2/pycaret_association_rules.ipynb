# %% [markdown]
# # **1. Install pycaret**

# %%
# !pip install pycaret==3.0.0.rc1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 538.1/538.1 kB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.8/81.8 kB 12.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 11.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 81.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 57.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 36.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 kB 15.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.6/172.6 kB 21.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 MB 11.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.5/17.5 MB 68.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 3.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# # **2. Check the pycaret version**

# %%
import pycaret
print(pycaret.__version__)
# Out:
# 3.0.0.rc1

# %% [markdown]
# # **3. Get the dataset from github**

# %%
import pandas as pd
dataset_url = 'https://raw.githubusercontent.com/neeharikasinghsjsu/cmpe255assignments/main/Lecture2_Assignments/Assignment2/dataset/groceries_dataset_association_rules.csv'
dataset = pd.read_csv(dataset_url)

# %% [markdown]
# # **4. Scan the dataset**

# %%
print("(Rows, Columns) in the dataset : ", dataset.shape, "\n\n")
dataset
# Out:
# (Rows, Columns) in the dataset :  (38765, 3)
#        Member_number        Date        itemDescription
# 0               1808  21-07-2015         tropical fruit
# 1               2552  05-01-2015             whole milk
# 2               2300  19-09-2015              pip fruit
# 3               1187  12-12-2015       other vegetables
# 4               3037  01-02-2015             whole milk
# ...              ...         ...                    ...
# 38760           4471  08-10-2014          sliced cheese
# 38761           2022  23-02-2014                  candy
# 38762           1097  16-04-2014               cake bar
# 38763           1510  03-12-2014  fruit/vegetable juice
# 38764           1521  26-12-2014               cat food
#
# [38765 rows x 3 columns]

# %% [markdown]
# # **5. Setup**

# %%
from pycaret.arules import *
#s = setup(data = dataset, transaction_id = 'Member_number', item_id = 'itemDescription')
as_rules = get_rules(data = dataset, transaction_id = 'Member_number', item_id = 'itemDescription')
# Out:
# WARNING:logs:/usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <style type="text/css">
# </style>
# <table id="T_99b63" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_99b63_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_99b63_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_99b63_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_99b63_row0_col1" class="data row0 col1" >8977</td>
#     </tr>
#     <tr>
#       <td id="T_99b63_row1_col0" class="data row1 col0" ># Transactions</td>
# ...

# %%
as_rules
# Out:
#                            antecedents         consequents  \
# 0    (other vegetables, bottled water)        (whole milk)
# 1           (other vegetables, yogurt)        (whole milk)
# 2                 (rolls/buns, yogurt)        (whole milk)
# 3       (other vegetables, rolls/buns)        (whole milk)
# 4                       (soda, yogurt)        (whole milk)
# 5             (other vegetables, soda)        (whole milk)
# 6   (other vegetables, tropical fruit)        (whole milk)
# 7                   (soda, rolls/buns)        (whole milk)
# 8                      (shopping bags)        (whole milk)
# 9          (other vegetables, sausage)        (whole milk)
# 10                      (bottled beer)        (whole milk)
# 11                 (frozen vegetables)        (whole milk)
# 12                              (beef)        (whole milk)
# 13                            (yogurt)        (whole milk)
# 14                       (canned beer)        (whole milk)
# ...
